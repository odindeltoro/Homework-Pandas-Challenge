# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
dfPurchaseData = pd.read_csv(file_to_load)
dfPurchaseData
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Result for player count
# Out:
#    Total Players
# 0            576

# %%
dfPurchaseData.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %%
dfPurchaseData.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   91.755128    3.050987
# std     225.310896    6.659444   52.697702    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   47.750000    1.980000
# 50%     389.500000   22.000000   92.000000    3.150000
# 75%     584.250000   25.000000  138.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
# Extract the list of unique count of players
playerCountdf = dfPurchaseData["SN"].unique()
playerCountdf
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Chanosian48', 'Inguron55', 'Haisrisuir60', 'Saelaephos52',
#        'Assjaskan73', 'Saesrideu94', 'Lisassa64', 'Lisirra25',
#        'Zontibe81', 'Reunasu60', 'Chamalo71', 'Iathenudil29',
#        'Phiarithdeu40', 'Siarithria38', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Reulae52',
#        'Sondilsaya62', 'Aerithriaphos45', 'Assosia88', 'Aidaillodeu39',
#        'Aelly27', 'Tyeosri53', 'Haerith37', 'Yasrisu92', 'Chanuchi25',
#        'Asur96', 'Iaralrgue74', 'Chanosia34', 'Aelin32', 'Ilosianya35',
#        'Zhisrisu83', 'Phaelap26', 'Raesty92', 'Palyon91', 'Tyisur83',
#        'Yaliru88', 'Yadanu52', 'Jiskimya77', 'Yadaphos40', 'Alo38',
# ...

# %%
# Extract the number of unique players
playerCountdf = dfPurchaseData["SN"].nunique()
playerCountdf
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Results of table Purchasing Analysis (Total)
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     179         $3.05                 780     $2,379.77

# %%
# Extract the number of unique Items
itemCountdf = dfPurchaseData["Item Name"].unique()
itemCountdf
# Out:
# array(['Extraction, Quickblade Of Trembling Hands', 'Frenzied Scimitar',
#        'Final Critic', 'Blindscythe', 'Fury', 'Dreamkiss',
#        'Interrogator, Blood Blade of the Queen', 'Abyssal Shard',
#        'Souleater', 'Ghastly Adamantite Protector',
#        'Singed Onyx Warscythe', 'Renewed Skeletal Katana',
#        "Bloodlord's Fetish", 'Bone Crushing Silver Skewer',
#        'Deadline, Voice Of Subtlety', 'Second Chance', 'Devine',
#        'Nirvana', 'Blazefury, Protector of Delusions',
#        'Despair, Favor of Due Diligence',
#        'Sun Strike, Jaws of Twisted Visions', 'Warped Fetish',
#        'Severance', 'Persuasion',
#        'Oathbreaker, Last Hope of the Breaking Storm', 'Demise',
#        'Blood-Forged Skeletal Spine',
#        'Stormbringer, Dark Blade of Ending Misery',
#        'Shadow Strike, Glory of Ending Hope', 'Striker',
#        'Wolf, Promise of the Moonwalker', "Faith's Scimitar",
# ...

# %%
# Extract the number of unique Items
itemCountdf = dfPurchaseData["Item Name"].nunique()
itemCountdf
# Out:
# 179

# %%
# Estimate Average Purchase Price
averagePurchasePrice = round(dfPurchaseData["Price"].mean(),2)
averagePurchasePrice = "${:,.2f}".format(averagePurchasePrice)
averagePurchasePrice
# Out:
# '$3.05'

# %%
# Estimate Total Number of Purchases
totalPurchases = dfPurchaseData["Purchase ID"].nunique()
totalPurchases
# Out:
# 780

# %%
# Estimate Total Revenue
totalRevenue = round(dfPurchaseData["Price"].sum(),2)
totalRevenue = "${:,.2f}".format(totalRevenue)
totalRevenue
# Out:
# '$2,379.77'

# %%
# Join the data in a single table
joinPurchasingAnalysisdf = pd.DataFrame({"Number of Unique Items": [itemCountdf],"Average Price": [averagePurchasePrice],"Number of Purchases": [totalPurchases],"Total Revenue": [totalRevenue]})
joinPurchasingAnalysisdf
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Results of Gender Demographics
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %%
# Extract data of table of variables needed
genderTable = dfPurchaseData[["SN","Gender"]]
genderTable
# Out:
#                 SN  Gender
# 0          Lisim78    Male
# 1      Lisovynya38    Male
# 2       Ithergue48    Male
# 3    Chamassasya86    Male
# 4        Iskosia90    Male
# ..             ...     ...
# 775     Aethedru70  Female
# 776         Iral74    Male
# 777     Yathecal72    Male
# 778        Sisur91    Male
# 779      Ennrian78    Male
#
# [780 rows x 2 columns]

# %%
# Drop out duplicates
genderTableSN = genderTable.drop_duplicates("SN")
genderTableSN
# Out:
#                 SN  Gender
# 0          Lisim78    Male
# 1      Lisovynya38    Male
# 2       Ithergue48    Male
# 3    Chamassasya86    Male
# 4        Iskosia90    Male
# ..             ...     ...
# 773         Hala31    Male
# 774     Jiskjask80    Male
# 775     Aethedru70  Female
# 777     Yathecal72    Male
# 778        Sisur91    Male
#
# [576 rows x 2 columns]

# %%
# Determine the separate values of Gender and its count
genderTableSN.Gender.value_counts()
totalGender = genderTableSN["SN"].size
genderTableSN
# Out:
#                 SN  Gender
# 0          Lisim78    Male
# 1      Lisovynya38    Male
# 2       Ithergue48    Male
# 3    Chamassasya86    Male
# 4        Iskosia90    Male
# ..             ...     ...
# 773         Hala31    Male
# 774     Jiskjask80    Male
# 775     Aethedru70  Female
# 777     Yathecal72    Male
# 778        Sisur91    Male
#
# [576 rows x 2 columns]

# %%
# Estimate Count of Male Players
genderMale = genderTableSN.loc[genderTableSN["Gender"] == "Male",:]
genderMaleCount = genderMale["Gender"].count()
genderMaleCount
# Out:
# 484

# %%
# Estimate Count of Female Players
genderFemale = genderTableSN.loc[genderTableSN["Gender"] == "Female",:]
genderFemaleCount = genderFemale["Gender"].count()
genderFemaleCount
# Out:
# 81

# %%
# Estimate Count of Other / Non-Disclosed
genderOther = genderTableSN.loc[genderTableSN["Gender"] == "Other / Non-Disclosed",:]
genderOtherCount = genderOther["Gender"].count()
genderOtherCount
# Out:
# 11

# %%
# Estimate Percentage of Male Players
genderMalePercentage = round((genderMaleCount/totalGender)*100,2)
genderMalePercentage = "{0:.2f}%".format(genderMalePercentage)
genderMalePercentage
# Out:
# '84.03%'

# %%
# Estimate Percentage of Female Players
genderFemalePercentage = round((genderFemaleCount/totalGender)*100,2)
genderFemalePercentage = "{0:.2f}%".format(genderFemalePercentage)
genderFemalePercentage
# Out:
# '14.06%'

# %%
# Estimate Percentage of Other / Non-Disclosed
genderOtherPercentage = round((genderOtherCount/totalGender)*100,2)
genderOtherPercentage = "{0:.2f}%".format(genderOtherPercentage)
genderOtherPercentage
# Out:
# '1.91%'

# %%
# Join the data in a single table
joinGenderdf = pd.DataFrame({"Gender":["Male","Female","Other / Non-Disclosed"], "Total Count": [genderMaleCount,genderFemaleCount,genderOtherCount],"Percentage of Players": [genderMalePercentage,genderFemalePercentage,genderOtherPercentage]})
joinGenderdf
# Out:
#                   Gender  Total Count Percentage of Players
# 0                   Male          484                84.03%
# 1                 Female           81                14.06%
# 2  Other / Non-Disclosed           11                 1.91%

# %%
Gender = ["Male","Female","Other / Non-Disclosed"]
genderPercentage = [84.03,14.06,1.91]
colors =["orange","lightcoral","lightskyblue"]
explode = (0.2, 0, 0)
plt.pie(genderPercentage, labels=Gender, autopct="%1.1f%%", startangle=100, colors=colors, shadow=True, explode=explode)
plt.xticks(rotation=180)
plt.axis("equal")
plt.title("Gender distribution")
plt.show()

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Results of Gender Purchasing Analysis
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
# The below each broken by genderExtract data of table of variables needed
genderPurchaseTable = dfPurchaseData[["Purchase ID","Gender","SN","Item Name","Price"]]
genderPurchaseTable
# Out:
#      Purchase ID  Gender             SN  \
# 0              0    Male        Lisim78
# 1              1    Male    Lisovynya38
# 2              2    Male     Ithergue48
# 3              3    Male  Chamassasya86
# 4              4    Male      Iskosia90
# ..           ...     ...            ...
# 775          775  Female     Aethedru70
# 776          776    Male         Iral74
# 777          777    Male     Yathecal72
# 778          778    Male        Sisur91
# 779          779    Male      Ennrian78
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# ...

# %%
#Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
totalFemale =dfPurchaseData["Gender"] == "Female"
totalMale =dfPurchaseData["Gender"] == "Male"
totalOther =dfPurchaseData["Gender"] == "Other / Non-Disclosed"
femaleCount =dfPurchaseData.loc[totalFemale,:]["SN"].nunique()
maleCount =dfPurchaseData.loc[totalMale,:]["SN"].nunique()
otherCount =dfPurchaseData.loc[totalOther,:]["SN"].nunique()
femalePurchaseDatadf = dfPurchaseData.loc[totalFemale, :]
malePurchaseDatadf = dfPurchaseData.loc[totalMale, :]
otherPurchaseDatadf = dfPurchaseData.loc[totalOther, :]

# Determine Purchase Count
femalePurchaseCount = femalePurchaseDatadf["Purchase ID"].count()
malePurchaseCount = malePurchaseDatadf["Purchase ID"].count()
otherPurchaseCount = otherPurchaseDatadf["Purchase ID"].count()

# Total Purchase Value
femaleTotalPurchaseValue = femalePurchaseDatadf["Price"].sum()
maleTotalPurchaseValue = malePurchaseDatadf["Price"].sum() 
otherTotalPurchaseValue = otherPurchaseDatadf["Price"].sum()

# Calculate Average Purchase Price
femalePurchaseAveragePrice = round(femaleTotalPurchaseValue / femalePurchaseCount, 2)
malePurchaseAveragePrice = round(maleTotalPurchaseValue / malePurchaseCount, 2)
otherPurchaseAveragePrice = round(otherTotalPurchaseValue / otherPurchaseCount, 2)

# Calculate Average Purchase Total per Person by Gender
femalePurchaseTotal = round(femaleTotalPurchaseValue / femaleCount, 2)
malePurchaseTotal = round(maleTotalPurchaseValue / maleCount, 2)
otherPurchaseTotal = round(otherTotalPurchaseValue / otherCount, 2)

# %%
#Create a summary data frame to hold the results
#Optional: give the displayed data cleaner formatting
#Display the summary data frame
femalePurchaseAveragePrice = "${:,.2f}".format(femalePurchaseAveragePrice)
malePurchaseAveragePrice = "${:,.2f}".format(malePurchaseAveragePrice)
otherPurchaseAveragePrice = "${:,.2f}".format(otherPurchaseAveragePrice)
femaleTotalPurchaseValue = "${:,.2f}".format(femaleTotalPurchaseValue)
maleTotalPurchaseValue = "${:,.2f}".format(maleTotalPurchaseValue)
otherTotalPurchaseValue = "${:,.2f}".format(otherTotalPurchaseValue)
femalePurchaseTotal = "${:,.2f}".format(femalePurchaseTotal)
malePurchaseTotal = "${:,.2f}".format(malePurchaseTotal)
otherPurchaseTotal = "${:,.2f}".format(otherPurchaseTotal)

genderPurchasingAnalysis = pd.DataFrame({"Purchase Count": [femalePurchaseCount, malePurchaseCount, otherPurchaseCount],"Average Purchase Price": [femalePurchaseAveragePrice, malePurchaseAveragePrice, otherPurchaseAveragePrice],"Total Purchase Value": [femaleTotalPurchaseValue, maleTotalPurchaseValue, otherTotalPurchaseValue],"Average Purchase Total per Person": [femalePurchaseTotal, malePurchaseTotal, otherPurchaseTotal]},index=["Female", "Male", "Other / Non-Disclosed"])
genderPurchasingAnalysis
# Out:
#                        Purchase Count Average Purchase Price  \
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Average Purchase Total per Person
# Female                             $361.94                             $4.47
# Male                             $1,967.64                             $4.07
# Other / Non-Disclosed               $50.19                             $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Results of Age Demographics
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %%
# Extract data of table of variables needed
ageDemographicTable = dfPurchaseData[["SN","Age","Purchase ID", "Price"]]
ageDemographicTable
# Out:
#                 SN  Age  Purchase ID  Price
# 0          Lisim78   20            0   3.53
# 1      Lisovynya38   40            1   1.56
# 2       Ithergue48   24            2   4.88
# 3    Chamassasya86   24            3   3.27
# 4        Iskosia90   23            4   1.44
# ..             ...  ...          ...    ...
# 775     Aethedru70   21          775   3.54
# 776         Iral74   21          776   1.63
# 777     Yathecal72   20          777   3.46
# 778        Sisur91    7          778   4.19
# 779      Ennrian78   24          779   4.60
#
# [780 rows x 4 columns]

# %%
# Drop out duplicates
ageDemographicTableSN = ageDemographicTable.drop_duplicates("SN")
ageDemographicTableSN
# Out:
#                 SN  Age  Purchase ID  Price
# 0          Lisim78   20            0   3.53
# 1      Lisovynya38   40            1   1.56
# 2       Ithergue48   24            2   4.88
# 3    Chamassasya86   24            3   3.27
# 4        Iskosia90   23            4   1.44
# ..             ...  ...          ...    ...
# 773         Hala31   21          773   1.02
# 774     Jiskjask80   11          774   4.19
# 775     Aethedru70   21          775   3.54
# 777     Yathecal72   20          777   3.46
# 778        Sisur91    7          778   4.19
#
# [576 rows x 4 columns]

# %%
# Search for Max age
ageDemographicTable.describe()
# Out:
#               Age  Purchase ID       Price
# count  780.000000   780.000000  780.000000
# mean    22.714103   389.500000    3.050987
# std      6.659444   225.310896    1.169549
# min      7.000000     0.000000    1.000000
# 25%     20.000000   194.750000    1.980000
# 50%     22.000000   389.500000    3.150000
# 75%     25.000000   584.250000    4.080000
# max     45.000000   779.000000    4.990000

# %%
# Establish bins for ages
# The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
binsAge = [0, 9, 14, 19, 24, 29, 34, 39, 45]
binsLabel = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
# Categorize the existing players using the age bins. Hint: use pd.cut()
dfPurchaseData["ageDemograpics"] = pd.cut(ageDemographicTableSN["Age"], binsAge, labels = binsLabel)

# %%
pd.cut(ageDemographicTableSN["Age"], binsAge)
# Out:
# 0      (19, 24]
# 1      (39, 45]
# 2      (19, 24]
# 3      (19, 24]
# 4      (19, 24]
#          ...
# 773    (19, 24]
# 774     (9, 14]
# 775    (19, 24]
# 777    (19, 24]
# 778      (0, 9]
# Name: Age, Length: 576, dtype: category
# Categories (8, interval[int64]): [(0, 9] < (9, 14] < (14, 19] < (19, 24] < (24, 29] < (29, 34] < (34, 39] < (39, 45]]

# %%
pd.cut(ageDemographicTableSN["Age"], binsAge, labels = binsLabel).value_counts()
# Out:
# 20-24    258
# 15-19    107
# 25-29     77
# 30-34     52
# 35-39     31
# 10-14     22
# <10       17
# 40+       12
# Name: Age, dtype: int64

# %%
totalAge = dfPurchaseData["ageDemograpics"]
totalAgeLower10 = dfPurchaseData["ageDemograpics"] == "<10"
totalAgeUntil14 = dfPurchaseData["ageDemograpics"] == "10-14"
totalAgeUntil19 = dfPurchaseData["ageDemograpics"] == "15-19"
totalAgeUntil24 = dfPurchaseData["ageDemograpics"] == "20-24"
totalAgeUntil29 = dfPurchaseData["ageDemograpics"] == "25-29"
totalAgeUntil34 = dfPurchaseData["ageDemograpics"] == "30-34"
totalAgeUntil39 = dfPurchaseData["ageDemograpics"] == "35-39"
totalAgeHigher40 = dfPurchaseData["ageDemograpics"] == "40+"
AgeLower10Count = dfPurchaseData.loc[totalAgeLower10,:]["SN"].nunique()
AgeUntil14Count = dfPurchaseData.loc[totalAgeUntil14,:]["SN"].nunique()
AgeUntil19Count = dfPurchaseData.loc[totalAgeUntil19,:]["SN"].nunique()
AgeUntil24Count = dfPurchaseData.loc[totalAgeUntil24,:]["SN"].nunique()
AgeUntil29Count = dfPurchaseData.loc[totalAgeUntil29,:]["SN"].nunique()
AgeUntil34Count = dfPurchaseData.loc[totalAgeUntil34,:]["SN"].nunique()
AgeUntil39Count = dfPurchaseData.loc[totalAgeUntil39,:]["SN"].nunique()
AgeHigher40Count = dfPurchaseData.loc[totalAgeHigher40,:]["SN"].nunique()
ageLower10PurchaseDatadf = dfPurchaseData.loc[totalAgeLower10, :]
ageUntil14PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil14, :]
ageUntil19PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil19, :]
ageUntil24PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil24, :]
ageUntil29PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil29, :]
ageUntil34PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil34, :]
ageUntil39PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil39, :]
ageHigher40PurchaseDatadf = dfPurchaseData.loc[totalAgeHigher40, :]

# %%
# Estimate Percentage by Age Group
ageLower10Percentage = round((AgeLower10Count/playerCountdf) *100 ,2)
ageUntil14Percentage = round((AgeUntil14Count/playerCountdf) *100 ,2)
ageUntil19Percentage = round((AgeUntil19Count/playerCountdf) *100 ,2)
ageUntil24Percentage = round((AgeUntil24Count/playerCountdf) *100 ,2)
ageUntil29Percentage = round((AgeUntil29Count/playerCountdf) *100 ,2)
ageUntil34Percentage = round((AgeUntil34Count/playerCountdf) *100 ,2)
ageUntil39Percentage = round((AgeUntil39Count/playerCountdf) *100 ,2)
ageHigher40Percentage = round((AgeHigher40Count/playerCountdf) *100 ,2)

# %%
# Create a summary data frame to hold the results
# Optional: round the percentage column to two decimal points
# Display Age Demographics Table
ageLower10Percentage = "{0:.2f}%".format(ageLower10Percentage)
ageUntil14Percentage = "{0:.2f}%".format(ageUntil14Percentage)
ageUntil19Percentage = "{0:.2f}%".format(ageUntil19Percentage)
ageUntil24Percentage = "{0:.2f}%".format(ageUntil24Percentage)
ageUntil29Percentage = "{0:.2f}%".format(ageUntil29Percentage)
ageUntil34Percentage = "{0:.2f}%".format(ageUntil34Percentage)
ageUntil39Percentage = "{0:.2f}%".format(ageUntil39Percentage)
ageHigher40Percentage = "{0:.2f}%".format(ageHigher40Percentage)

ageDemographicsdf = pd.DataFrame({"Age segmentation": ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"],"Total Count": [AgeLower10Count, AgeUntil14Count, AgeUntil19Count, AgeUntil24Count, AgeUntil29Count, AgeUntil34Count, AgeUntil39Count, AgeHigher40Count],"Percentage of Players": [ageLower10Percentage, ageUntil14Percentage, ageUntil19Percentage, ageUntil24Percentage, ageUntil29Percentage, ageUntil34Percentage, ageUntil39Percentage, ageHigher40Percentage]})
ageDemographicsdf
# Out:
#   Age segmentation  Total Count Percentage of Players
# 0              <10           17                 2.95%
# 1            10-14           22                 3.82%
# 2            15-19          107                18.58%
# 3            20-24          258                44.79%
# 4            25-29           77                13.37%
# 5            30-34           52                 9.03%
# 6            35-39           31                 5.38%
# 7              40+           12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Results of Purchasing Analysis Age
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %%
# Bin the purchase_data data frame by age
binsAge = [0, 9, 14, 19, 24, 29, 34, 39, 45]
binsLabel = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
dfPurchaseData["ageDemograpics"] = pd.cut(dfPurchaseData["Age"], binsAge, labels = binsLabel)

# %%
# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
totalAge = dfPurchaseData["ageDemograpics"]
totalAgeLower10 = dfPurchaseData["ageDemograpics"] == "<10"
totalAgeUntil14 = dfPurchaseData["ageDemograpics"] == "10-14"
totalAgeUntil19 = dfPurchaseData["ageDemograpics"] == "15-19"
totalAgeUntil24 = dfPurchaseData["ageDemograpics"] == "20-24"
totalAgeUntil29 = dfPurchaseData["ageDemograpics"] == "25-29"
totalAgeUntil34 = dfPurchaseData["ageDemograpics"] == "30-34"
totalAgeUntil39 = dfPurchaseData["ageDemograpics"] == "35-39"
totalAgeHigher40 = dfPurchaseData["ageDemograpics"] == "40+"
AgeLower10Count = dfPurchaseData.loc[totalAgeLower10,:]["SN"].nunique()
AgeUntil14Count = dfPurchaseData.loc[totalAgeUntil14,:]["SN"].nunique()
AgeUntil19Count = dfPurchaseData.loc[totalAgeUntil19,:]["SN"].nunique()
AgeUntil24Count = dfPurchaseData.loc[totalAgeUntil24,:]["SN"].nunique()
AgeUntil29Count = dfPurchaseData.loc[totalAgeUntil29,:]["SN"].nunique()
AgeUntil34Count = dfPurchaseData.loc[totalAgeUntil34,:]["SN"].nunique()
AgeUntil39Count = dfPurchaseData.loc[totalAgeUntil39,:]["SN"].nunique()
AgeHigher40Count = dfPurchaseData.loc[totalAgeHigher40,:]["SN"].nunique()
ageLower10PurchaseDatadf = dfPurchaseData.loc[totalAgeLower10, :]
ageUntil14PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil14, :]
ageUntil19PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil19, :]
ageUntil24PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil24, :]
ageUntil29PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil29, :]
ageUntil34PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil34, :]
ageUntil39PurchaseDatadf = dfPurchaseData.loc[totalAgeUntil39, :]
ageHigher40PurchaseDatadf = dfPurchaseData.loc[totalAgeHigher40, :]

# Estimate Purchase Count
ageLower10PurchaseCount = ageLower10PurchaseDatadf["Purchase ID"].count()
ageUntil14PurchaseCount = ageUntil14PurchaseDatadf["Purchase ID"].count()
ageUntil19PurchaseCount = ageUntil19PurchaseDatadf["Purchase ID"].count()
ageUntil24PurchaseCount = ageUntil24PurchaseDatadf["Purchase ID"].count()
ageUntil29PurchaseCount = ageUntil29PurchaseDatadf["Purchase ID"].count()
ageUntil34PurchaseCount = ageUntil34PurchaseDatadf["Purchase ID"].count()
ageUntil39PurchaseCount = ageUntil39PurchaseDatadf["Purchase ID"].count()
ageHigher40PurchaseCount = ageHigher40PurchaseDatadf["Purchase ID"].count()

# Estimate Total Purchase Value
ageLower10PurchaseValue = ageLower10PurchaseDatadf["Price"].sum()
ageUntil14PurchaseValue = ageUntil14PurchaseDatadf["Price"].sum()
ageUntil19PurchaseValue = ageUntil19PurchaseDatadf["Price"].sum()
ageUntil24PurchaseValue = ageUntil24PurchaseDatadf["Price"].sum()
ageUntil29PurchaseValue = ageUntil29PurchaseDatadf["Price"].sum()
ageUntil34PurchaseValue = ageUntil34PurchaseDatadf["Price"].sum()
ageUntil39PurchaseValue = ageUntil39PurchaseDatadf["Price"].sum()
ageHigher40PurchaseValue = ageHigher40PurchaseDatadf["Price"].sum()

# Estimate Average Purchase Price
ageLower10PurchaseAveragePrice = round(ageLower10PurchaseValue / ageLower10PurchaseCount, 2)
ageUntil14PurchaseAveragePrice = round(ageUntil14PurchaseValue / ageUntil14PurchaseCount, 2)
ageUntil19PurchaseAveragePrice = round(ageUntil19PurchaseValue / ageUntil19PurchaseCount, 2)
ageUntil24PurchaseAveragePrice = round(ageUntil24PurchaseValue / ageUntil24PurchaseCount, 2)
ageUntil29PurchaseAveragePrice = round(ageUntil29PurchaseValue / ageUntil29PurchaseCount, 2)
ageUntil34PurchaseAveragePrice = round(ageUntil34PurchaseValue / ageUntil34PurchaseCount, 2)
ageUntil39PurchaseAveragePrice = round(ageUntil39PurchaseValue / ageUntil39PurchaseCount, 2)
ageHigher40PurchaseAveragePrice = round(ageHigher40PurchaseValue / ageHigher40PurchaseCount, 2)

# Estimate Average Purchase Total per Person by Age Group
ageLower10PurchaseTotal = round(ageLower10PurchaseValue / AgeLower10Count, 2)
ageUntil14PurchaseTotal = round(ageUntil14PurchaseValue / AgeUntil14Count, 2)
ageUntil19PurchaseTotal = round(ageUntil19PurchaseValue / AgeUntil19Count, 2)
ageUntil24PurchaseTotal = round(ageUntil24PurchaseValue / AgeUntil24Count, 2)
ageUntil29PurchaseTotal = round(ageUntil29PurchaseValue / AgeUntil29Count, 2)
ageUntil34PurchaseTotal = round(ageUntil34PurchaseValue / AgeUntil34Count, 2)
ageUntil39PurchaseTotal = round(ageUntil39PurchaseValue / AgeUntil39Count, 2)
ageHigher40PurchaseTotal = round(ageHigher40PurchaseValue / AgeHigher40Count, 2)

# %%
# Create a summary data frame to hold the results
# Optional: give the displayed data cleaner formatting
# Display the summary data frame
ageLower10PurchaseValue = "${:,.2f}".format(ageLower10PurchaseValue)
ageUntil14PurchaseValue = "${:,.2f}".format(ageUntil14PurchaseValue)
ageUntil19PurchaseValue = "${:,.2f}".format(ageUntil19PurchaseValue)
ageUntil24PurchaseValue = "${:,.2f}".format(ageUntil24PurchaseValue)
ageUntil29PurchaseValue = "${:,.2f}".format(ageUntil29PurchaseValue)
ageUntil34PurchaseValue = "${:,.2f}".format(ageUntil34PurchaseValue)
ageUntil39PurchaseValue = "${:,.2f}".format(ageUntil39PurchaseValue)
ageHigher40PurchaseValue = "${:,.2f}".format(ageHigher40PurchaseValue)
ageLower10PurchaseAveragePrice = "${:,.2f}".format(ageLower10PurchaseAveragePrice)
ageUntil14PurchaseAveragePrice = "${:,.2f}".format(ageUntil14PurchaseAveragePrice)
ageUntil19PurchaseAveragePrice = "${:,.2f}".format(ageUntil19PurchaseAveragePrice)
ageUntil24PurchaseAveragePrice = "${:,.2f}".format(ageUntil24PurchaseAveragePrice)
ageUntil29PurchaseAveragePrice = "${:,.2f}".format(ageUntil29PurchaseAveragePrice)
ageUntil34PurchaseAveragePrice = "${:,.2f}".format(ageUntil34PurchaseAveragePrice)
ageUntil39PurchaseAveragePrice = "${:,.2f}".format(ageUntil39PurchaseAveragePrice)
ageHigher40PurchaseAveragePrice = "${:,.2f}".format(ageHigher40PurchaseAveragePrice)
ageLower10PurchaseTotal = "${:,.2f}".format(ageLower10PurchaseTotal)
ageUntil14PurchaseTotal = "${:,.2f}".format(ageUntil14PurchaseTotal)
ageUntil19PurchaseTotal = "${:,.2f}".format(ageUntil19PurchaseTotal)
ageUntil24PurchaseTotal = "${:,.2f}".format(ageUntil24PurchaseTotal)
ageUntil29PurchaseTotal = "${:,.2f}".format(ageUntil29PurchaseTotal)
ageUntil34PurchaseTotal = "${:,.2f}".format(ageUntil34PurchaseTotal)
ageUntil39PurchaseTotal = "${:,.2f}".format(ageUntil39PurchaseTotal)
ageHigher40PurchaseTotal = "${:,.2f}".format(ageHigher40PurchaseTotal)

ageDemographicPurchasingAnalysis = pd.DataFrame({"Age segmentation": ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"], "Purchase Count": [ageLower10PurchaseCount, ageUntil14PurchaseCount, ageUntil19PurchaseCount, ageUntil24PurchaseCount, ageUntil29PurchaseCount, ageUntil34PurchaseCount, ageUntil39PurchaseCount, ageHigher40PurchaseCount],"Average Purchase Price": [ageLower10PurchaseAveragePrice, ageUntil14PurchaseAveragePrice, ageUntil19PurchaseAveragePrice, ageUntil24PurchaseAveragePrice, ageUntil29PurchaseAveragePrice, ageUntil34PurchaseAveragePrice, ageUntil39PurchaseAveragePrice, ageHigher40PurchaseAveragePrice],"Total Purchase Value": [ageLower10PurchaseValue, ageUntil14PurchaseValue, ageUntil19PurchaseValue, ageUntil24PurchaseValue, ageUntil29PurchaseValue, ageUntil34PurchaseValue, ageUntil39PurchaseValue, ageHigher40PurchaseValue],"Average Purchase Total per Person": [ageLower10PurchaseTotal, ageUntil14PurchaseTotal, ageUntil19PurchaseTotal, ageUntil24PurchaseTotal, ageUntil29PurchaseTotal, ageUntil34PurchaseTotal, ageUntil39PurchaseTotal, ageHigher40PurchaseTotal]})
ageDemographicPurchasingAnalysis
# Out:
#   Age segmentation  Purchase Count Average Purchase Price  \
# 0              <10              23                  $3.35
# 1            10-14              28                  $2.96
# 2            15-19             136                  $3.04
# 3            20-24             365                  $3.05
# 4            25-29             101                  $2.90
# 5            30-34              73                  $2.93
# 6            35-39              41                  $3.60
# 7              40+              13                  $2.94
#
#   Total Purchase Value Average Purchase Total per Person
# 0               $77.13                             $4.54
# 1               $82.78                             $3.76
# 2              $412.89                             $3.86
# 3            $1,114.06                             $4.32
# 4              $293.00                             $3.81
# 5              $214.00                             $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Results of Top Spenders
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
# Run basic calculations to obtain the results in the table below
# SN
# Purchase Count
# Average Purchase Price
# Total Purchase Value
spenderPurchaseTabledf = dfPurchaseData.groupby("SN").agg({"Price":["count", "mean", "sum"]})
spenderPurchaseTabledf.columns = spenderPurchaseTabledf.columns.map("_".join)
spenderPurchaseTabledf.columns = ["Purchase Count", "Average Purchase Price", "Total Purchase Value"]
spenderPurchaseTabledf
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                1                2.280000                  2.28
# Adastirin33                 1                4.480000                  4.48
# Aeda94                      1                4.910000                  4.91
# Aela59                      1                4.320000                  4.32
# Aelaria33                   1                1.790000                  1.79
# ...                       ...                     ...                   ...
# Yathecal82                  3                2.073333                  6.22
# Yathedeu43                  2                3.010000                  6.02
# Yoishirrala98               1                4.580000                  4.58
# Zhisrisu83                  2                3.945000                  7.89
# Zontibe81                   3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
# Create a summary data frame to hold the results
# Sort the total purchase value column in descending order
# Optional: give the displayed data cleaner formatting
# Display a preview of the summary data frame
# Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
spenderPurchaseTabledf["Purchase Count"] = spenderPurchaseTabledf["Purchase Count"]
spenderPurchaseTabledf["Average Purchase Price"] = round(spenderPurchaseTabledf["Average Purchase Price"],2)
spenderPurchaseTabledf["Total Purchase Value"] = round(spenderPurchaseTabledf["Total Purchase Value"],2)
topSpenderPurchasedf = spenderPurchaseTabledf.nlargest(5, ["Total Purchase Value"])
topSpenderPurchasedf
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                    3.79                 18.96
# Idastidru52               4                    3.86                 15.45
# Chamjask73                3                    4.61                 13.83
# Iral74                    4                    3.40                 13.62
# Iskadarya95               3                    4.37                 13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Results of Popular Items
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
# Retrieve the Item ID, Item Name, and Item Price columns
# Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
# Item ID
# Item Name
# Purchase Count
# Item Price
# Total Purchase Value
popularItemsTabledf = dfPurchaseData[["Item ID","Item Name", "Price"]]
popularItemsdf = popularItemsTabledf.groupby(["Item ID","Item Name"]).agg({"Price":["count", "mean", "sum"]})
popularItemsdf.columns = ["Purchase Count","Item Price" , "Total Purchase Value"]
popularItemsdf
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# ...                                                              ...
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 179     Wolf, Promise of the Moonwalker                            6
# 181     Reaper's Toll                                              5
# 182     Toothpick                                                  3
# 183     Dragon's Greatsword                                        3
#
#                                                       Item Price  \
# Item ID Item Name
# ...

# %%
# Create a summary data frame to hold the results
# Sort the purchase count column in descending order
# Optional: give the displayed data cleaner formatting
# Display a preview of the summary data frame
# Identify the 5 most popular items by purchase count, then list (in a table):
popularItemsdf["Purchase Count"] = popularItemsdf["Purchase Count"]
popularItemsdf["Item Price"] = round(popularItemsdf["Item Price"],2)
popularItemsdf["Total Purchase Value"] = round(popularItemsdf["Total Purchase Value"],2)
topPopularItemsdf = popularItemsdf.nlargest(10, ["Purchase Count"])
topPopularItemsdf
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 132     Persuasion                                                 9
# 145     Fiery Glass Crusader                                       9
# 19      Pursuit, Cudgel of Necromancy                              8
# 34      Retribution Axe                                            8
# 37      Shadow Strike, Glory of Ending Hope                        8
# 59      Lightning, Etcher of the King                              8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                        4.61
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Results of Profitable Items
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
# Item ID
# Item Name
# Purchase Count
# Item Price
# Total Purchase Value
# Sort the above table by total purchase value in descending order
# Optional: give the displayed data cleaner formatting
# Display a preview of the data frame
# Identify the 5 most profitable items by total purchase value, then list (in a table):
topPopularItemsdf = popularItemsdf.nlargest(10, ["Total Purchase Value"])
topPopularItemsdf
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
# 59      Lightning, Etcher of the King                              8
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 78      Glimmer, Ender of the Moon                                 7
# 72      Winter's Bite                                              8
# 132     Persuasion                                                 9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                        4.61
# ...

# %% [markdown]
# # Trends based on data

# %% [markdown]
# Most players have between 15 and 29 years old and are men. Each player spend around 4 USD on average. The favorite items are Final Critic and Oathbreaker. The average price of items are around 3 USD.
#
# Marketing campaigns for publicity of items can be directed for loyalty to men players between 20 to 24 years old which have the most of players. Another alternative is to atract more players such as teenagers or adults older than 30 years with special campaigns for them or design special items for women which have lot of growth market potential.
